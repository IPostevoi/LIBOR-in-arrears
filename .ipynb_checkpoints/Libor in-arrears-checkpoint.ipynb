# %% [markdown]
# ### Параметры

# %%
import numpy as np
from scipy.integrate import quad
import scipy
from scipy import stats
import matplotlib
import matplotlib.pyplot as plt
from scipy.interpolate import spline
# %matplotlib inline

# %%
folder = 'pics/'
font_size = 14
legend_size = 15
grid_thick = 1.2
line_thick = 2.5
matplotlib.rcParams.update({'font.size': font_size})

# %%
tau = 0.5
a = 0.7
b = 0.05
theta = a * b
sigma = 0.1
T_n = 30.
r_t = 0.05

# %%
def B(t, T):
    return (1 - np.e ** (- a * (T - t))) / a


def A(t, T):
    return np.e ** ((B(t, T) - (T - t)) * (theta / a - sigma ** 2 / (2 * a ** 2)) - sigma ** 2 * B(t, T) ** 2 / (4 * a))

# %%
def P(t, T):
    return A(t, T) * np.e ** (- r_t * B(t, T))

# %%
def libor(t, T1, T2):
    return (P(t, T1) - P(t, T2)) / (tau * P(t, T2))

# %%
def convexity_adj(t, T1, T2):
    
    I = (sigma**2 / a**2) * (1/(2*a) - 1/(2*a) * np.e ** (-2*a*(T1-t)) -\
                           1/a * np.e**(-a*(T2-T1)) + 1/(a) * np.e**(-a*(T1+T2) + 2*a*t) + \
                           1/(2*a) * np.e**(-2*a*(T2-T1)) - 1/(2*a) * np.e**(-2*a*(T2-t))) 
                           
    return ((P(t, T2) / (tau * P(t, T1))) * ((P(t, T1) / P(t, T2))**2 * np.e ** I - 2 * (P(t, T1) / P(t, T2)) + 1) + \
                            libor(t, T1, T2) * (P(t, T2) - P(t, T1)) / P(t, T1))

# %%
def convexity_adj_earl(t, T1, Te, T2):
    
    I = (sigma**2 / a**2) * 1/(2*a) * (np.e**(-a*(T1-Te)) - np.e**(-a*(T1+Te-2*t)) - np.e**(-a*(T2-Te)) + \
                                       np.e**(-a*(T2+Te-2*t)) - np.e**(-a*(T1+T2-2*Te)) + np.e**(-a*(T1+T2-2*t)) + \
                                       np.e**(-2*a*(T2-Te)) - np.e**(-2*a*(T2-t)))
    
    return libor(t, T1, T2) * (P(t, T2)-P(t, Te)) / P(t, Te) + \
           P(t, T2)/(P(t, Te)*tau) * (P(t, T1)*P(t, Te)/(P(t, T2)*P(t, T2))*np.e**I - P(t, T1)/P(t, T2) - P(t, Te)/P(t, T2) + 1)

# %%
def convexity_adj_later(t, T1, Tl, T2):
    
    I = (sigma**2 / a**2) * 1/(2*a) * (np.e**(-a*(Tl-T1)) - np.e**(-a*(T1+Tl-2*t)) - np.e**(-a*(T2-T1)) + \
                                       np.e**(-a*(T1+T2-2*t)) - np.e**(-a*(T2+Tl-2*T1)) + np.e**(-a*(T2+Tl-2*t)) + \
                                       np.e**(-2*a*(T2-T1))-np.e**(-2*a*(T2-t)))
    
    return libor(t, T1, T2) * (P(t, T2)-P(t, Tl)) / P(t, Tl) + \
           P(t, T2)/(P(t, Tl)*tau) * (P(t, T1)*P(t, Tl)/(P(t, T2)*P(t, T2))*np.e**I - P(t, T1)/P(t, T2) - P(t, Tl)/P(t, T2) + 1)

# %%
def convexity_after_T2(t, Tl, T1, T2):
    
    I = (sigma**2 / a**2) * 1/(2*a) * (np.e**(-a*(Tl-T1)) - np.e**(-a*(T1+Tl-2*t)) - np.e**(-a*(T2-T1)) + \
                                       np.e**(-a*(T1+T2-2*t)) - np.e**(-a*(T2+Tl-2*T1)) + np.e**(-a*(T2+Tl-2*t)) + \
                                       np.e**(-2*a*(T2-T1))-np.e**(-2*a*(T2-t)))
    
    return P(t, T2)/(P(t, Tl)*tau) * (P(t, Tl)/P(t, T2)*P(t, T1)/P(t,T2)*np.e**I - P(t, Tl)/P(t,T2)) - libor(t, T1, T2)

# %%
def asympt(t, Tpay, T1, T2):
    
    J = sigma**2/(2*a**3) * (np.e**(-a*abs(T1-Tpay))-np.e**(-a*((T2-Tpay) if T1>Tpay else tau)) + \
        np.e**(-2*a*((T2-Tpay) if T1>Tpay else tau)) - np.e**(-a*(abs(T1-Tpay) + T2 - Tpay + max([0, Tpay-T1]))))
    
    return 1/tau * np.e**((theta/a-sigma**2/(2*a))*tau) * (np.e**J - 1)

# %%
asympt(0, 0.5, 0.5, 1)*10000
# Out:
# 25.99262841013837

# %%
1/tau * np.e**((theta/a-sigma**2/(2*a))*tau)
# Out:
# 2.0433196240603713

# %%
round(asympt(0, 0.7, 0, 0.5) * 10000,2)
# Out:
# -8.1

# %%
Tpay = 0.7
T1=0
T2=0.5

# %%
max([0, Tpay-T1])
# Out:
# 0.7

# %%
max([0, Tpay-T1])
# Out:
# 0.7

# %%
limP1 = np.e**((theta/a - sigma**2/(2*a))*tau)
limP2 = np.e**(-(theta/a - sigma**2/(2*a))*tau)

limI = sigma**2/(a**2) * (1/(2*a) - 1/a*np.e**(-a*tau) + 1/(2*a)*np.e**(-2*a*tau))

asymp1 = 1/tau * ((limP1 - 1) * (limP2 - 1)) + 1/tau * limP2 * (limP1**2 * np.e**limI - 2*limP1 + 1)

asymp1 *= 10000

print asymp1
# Out:
# 25.9926284101

# %%
1/tau * np.e**((theta/a-sigma**2/(2*a))*tau) * (np.e**(sigma**2/(2*a**3) * (1 - 2*np.e**(-a*tau) + np.e**(-2*a*tau))) - 1) * 10000
# Out:
# 25.99262841013837

# %%
1/tau * (np.e**(theta/a - sigma**2/(2*a))*tau)
# Out:
# 1.0437887715175542

# %%
taus = 1
limP1 = np.e**((theta/a - sigma**2/(2*a))*tau)
limP2 = np.e**(-(theta/a - sigma**2/(2*a))*tau)
limPs1 = np.e**((theta/a - sigma**2/(2*a))*taus)
limPs2 = np.e**(-(theta/a - sigma**2/(2*a))*taus)

limIs = sigma**2/(2*a**3) * (np.e**(-a*0.5) - np.e**(-a*taus) - np.e**(-a*1.5) + np.e**(-2*a*taus))

asymp2 = 1/tau * ((limP1 - 1) * (limPs2 - 1)) + 1/tau * limPs2 * (limP1*limPs1 * np.e**limIs - limP1 - limPs1 + 1)

asymp2 *= 10000

print asymp2
# Out:
# 31.2282488428

# %%
taup = 0.3
limP1 = np.e**((theta/a - sigma**2/(2*a))*tau)
limP2 = np.e**(-(theta/a - sigma**2/(2*a))*tau)
limPp1 = np.e**((theta/a - sigma**2/(2*a))*taup)
limPp2 = np.e**(-(theta/a - sigma**2/(2*a))*taup)

limIp = sigma**2/(2*a**3) * (np.e**(-a* 0.2) - np.e**(-a*tau) - np.e**(-a*0.7) + np.e**(-2*a*tau))

asymp3 = 1/tau * ((limP1 - 1) * (limPp2 - 1)) + 1/tau * limPp2 * (limP1*limPp1 * np.e**limIp - limP1 - limPp1 + 1)

asymp3 *= 10000

print asymp3
# Out:
# 14.4897857194

# %%
taup = 0.2
limP1 = np.e**((theta/a - sigma**2/(2*a))*tau)
limP2 = np.e**(-(theta/a - sigma**2/(2*a))*tau)
limPp1 = np.e**((theta/a - sigma**2/(2*a))*taup)
limPp2 = np.e**(-(theta/a - sigma**2/(2*a))*taup)

limIp = sigma**2/(2*a**3) * (np.e**(-a* 0.7) - np.e**(-a*tau) - np.e**(-a*1.2) + np.e**(-2*a*tau))

asymp4 = 1/tau * limPp1 * (limP1*limPp2 * np.e**limIp - limPp2) - 1/tau * (limP1-1)

asymp4 *= 10000

print asymp4
# Out:
# -8.09629021922

# %%
a*b
# Out:
# 0.034999999999999996

# %%
0.7**2
# Out:
# 0.48999999999999994

# %%
T = np.arange(0, T_n, tau)

# %%
tau * P(0, 1.5) / ( P(0, 1))
# Out:
# 0.48850002112458846

# %%
t=0.0
T1=0.0
T2=0.5
I = sigma**2 / a**2 * (1/(2*a) - 1/(2*a) * np.e ** (-2*a*(T1-t)) -\
                           1/a * np.e**(-a*(T2-T1)) + 1/(2*a) * np.e**(-a*(T1+T2) + 2*a*t) + \
                           1/(2*a) * np.e**(-2*a*(T2-T1)) - 1/(2*a) * np.e**(-2*a*(T2-t)))

# %%
((P(t, T1) / P(t, T2))**2 * np.e**(3 * I) - 2 * (P(t, T1) / P(t, T2)) + 1) * P(t, T1)
# Out:
# -0.031260385421041814

# %%
(P(t, T1) / P(t, T2)) ** 2 * np.e**I
# Out:
# 1.0401910975867603

# %%
np.e**I
# Out:
# 0.9897801599858889

# %%
convexity1 = np.zeros(len(T))
convexity1_vol = np.zeros(len(T))
convexity2 = np.zeros(len(T))
convexity_earl = np.zeros(len(T))
convexity_later = np.zeros(len(T))
convexity_after = np.zeros(len(T))
libor1 = np.zeros(len(T))
for i in np.arange(len(T)-1):
    convexity1[i] = convexity_adj(0, T[i], T[i+1])
    convexity_earl[i] = convexity_adj_earl(0, T[i], T[i]-0.5, T[i+1])
    convexity_later[i] = convexity_adj_later(0, T[i], T[i]+0.2, T[i+1])
    libor1[i] = libor(0, T[i], T[i+1])
    convexity_after[i] = convexity_after_T2(0, T[i+1] + 0.2, T[i], T[i+1])
    
b = 0.5
theta = a * b

convexity2 = np.zeros(len(T))
for i in np.arange(len(T)-1):
    convexity2[i] = convexity_adj(0, T[i], T[i+1])

# %%
T_new = np.linspace(T.min(), T.max(), 300)
conv1_smooth = spline(T, convexity1, T_new)
conv2_smooth = spline(T, convexity2, T_new)
conv_earl_smooth = spline(T, convexity_earl, T_new)
conv_later_smooth = spline(T, convexity_later, T_new)
libor_smooth = spline(T, libor1, T_new)

fig = plt.figure(figsize=(8, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(T_new, conv1_smooth * 10000, color=(0, 0, 0), label='$\\theta = 0.035$', linewidth=line_thick)
plt.plot(T_new, conv2_smooth * 10000, color=(0, 0, 0), label='$\\theta = 0.35$', linewidth=line_thick, ls="-.")
plt.legend(prop={'size':legend_size})
plt.axis([0, 10, 0, 36])
plt.grid(True, linewidth=grid_thick)
# plt.title(u'Поправка к форвардной LIBOR ставке, bps(0.01%)', fontsize=15)
plt.ylabel('$CA(t, T_i, T_{i+1})$, bps', fontsize=legend_size)
plt.xlabel(u'$T_i$, years', fontsize=legend_size)
plt.tight_layout()
plt.show()

fig.savefig(folder + 'conv-adj.png', dpi=fig.dpi, transparent=True)
# Out:
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   after removing the cwd from sys.path.
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   """
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: `spline` is deprecated!
# ...

# %%
fig, ax1 = plt.subplots(figsize=(8, 6), dpi= 80, facecolor='w', edgecolor='k')
ax1.set_ylabel('$CA(t, T_i, T_{i+1})$, bps', fontsize=legend_size)
ax1.set_xlabel(u'$T_i$, years', fontsize=legend_size)
ax1.plot(T_new, conv1_smooth * 10000, color=(0, 0, 0), label='convexity adjustment', linewidth=line_thick)
ax1.legend(prop={'size':legend_size}, loc=3)
ax1.axis([0, 10, 0, 36])
ax1.grid(True, linewidth=grid_thick)

ax2 = ax1.twinx()
ax2.set_ylabel('forward LIBOR rate, bps', fontsize=legend_size)
ax2.plot(T_new, libor_smooth*10000, color=(0, 0, 0), label='LIBOR', linewidth=line_thick, ls="-.")
ax2.legend(prop={'size':legend_size}, loc=4)

ax1.axhline(asymp1, c='black', ls='--')
ax1.text(-1, asymp1, round(asymp1, 2))

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.tight_layout()
plt.show()

fig.savefig(folder + 'conv-adj-two.png', dpi=fig.dpi, transparent=True)

# %%
b_floor = 0.01
b_ceil = 2
th = np.linspace(a*b_floor, a*b_ceil, 10000)
convexity_theta = np.zeros(len(th))
T1 = 5
T2 = T1 + tau
for i in np.arange(len(th)):
    theta = th[i]
    convexity_theta[i] = convexity_adj(0, T1, T2)

# %%
fig = plt.figure(figsize=(8, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(th, convexity_theta * 10000, color=(0, 0, 0), linewidth=line_thick)
# plt.legend(prop={'size':13})
# plt.axis([0, 10, 0, 36])
plt.grid(True, linewidth=grid_thick)
# plt.title(u'Поправка к форвардной LIBOR ставке, bps(0.01%)', fontsize=15)
plt.ylabel('$CA(0, 5, 5.5)$, bps', fontsize=legend_size)
plt.xlabel(u'$\\theta$', fontsize=legend_size)
plt.tight_layout()
plt.show()

fig.savefig(folder + 'conv-adj-mean_rev.png', dpi=fig.dpi, transparent=True)

# %%
b_floor = 0
b_ceil = 0.3
s = np.linspace(a*b_floor, a*b_ceil, 10000)
convexity_sigma = np.zeros(len(th))
theta = 0.35
T1 = 5
T2 = T1 + tau
for i in np.arange(len(th)):
    sigma = s[i]
    convexity_sigma[i] = convexity_adj(0, T1, T2)

# %%
fig = plt.figure(figsize=(8, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(s*100, convexity_sigma * 10000, color=(0, 0, 0), linewidth=line_thick)
# plt.legend(prop={'size':13})
# plt.axis([0, 10, 0, 0.00000000001])
plt.grid(True, linewidth=grid_thick)
# plt.title(u'Поправка к форвардной LIBOR ставке, bps(0.01%)', fontsize=15)
plt.ylabel('$CA(0, 5, 5.5)$, bps', fontsize=legend_size)
plt.xlabel(u'$\\sigma, \%$', fontsize=legend_size)
plt.tight_layout()
plt.show()

fig.savefig(folder + 'conv-adj-vol.png', dpi=fig.dpi, transparent=True)

# %% [markdown]
# ## С двумя разными волами

# %%
b = 0.05
theta = a * b

convexity_vol1 = np.zeros(len(T))
convexity_vol2 = np.zeros(len(T))
for i in np.arange(len(T)-1):
    
    convexity_vol1[i] = convexity_adj(0, T[i], T[i+1])
    sigma = 0.11
    convexity_vol2[i] = convexity_adj(0, T[i], T[i+1])
    sigma = 0.1

convexity2 = np.zeros(len(T))
for i in np.arange(len(T)-1):
    convexity2[i] = convexity_adj(0, T[i], T[i+1])

# %%
conv_vol1_smooth = spline(T, convexity_vol1, T_new)
conv_vol2_smooth = spline(T, convexity_vol2, T_new)

fig = plt.figure(figsize=(8, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(T_new, conv_vol1_smooth * 10000, color=(0, 0, 0), label='$\\sigma = 10\%$', linewidth=line_thick)
plt.plot(T_new, conv_vol2_smooth * 10000, color=(0, 0, 0), label='$\\sigma = 11\%$', linewidth=line_thick, ls="-.")
plt.legend(prop={'size':legend_size}, loc=4)
plt.axis([0, 10, 0, 36])
plt.grid(True, linewidth=grid_thick)
# plt.title(u'Поправка к форвардной LIBOR ставке, bps(0.01%)', fontsize=15)
plt.ylabel('$CA(t, T_i, T_{i+1})$, bps', fontsize=legend_size)
plt.xlabel(u'$T_i$, years', fontsize=legend_size)
plt.tight_layout()
plt.show()

fig.savefig(folder + 'conv-adj_vols.png', dpi=fig.dpi, transparent=True)
# Out:
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
T_new = np.linspace(T.min(), T.max(), 300)
conv1_smooth = spline(T, convexity1, T_new)
conv2_smooth = spline(T, convexity2, T_new)
conv_earl_smooth = spline(T[1:], convexity_earl[1:], T_new[5:])
conv_later_smooth = spline(T, convexity_later, T_new)
conv_after_smooth = spline(T, convexity_after, T_new)
libor_smooth = spline(T, libor1, T_new)

fig = plt.figure(figsize=(8, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(T_new, conv1_smooth*10000, label='$T_{pay}=T_1$', linewidth=line_thick)
plt.plot(T_new[5:], conv_earl_smooth*10000, label='$t<T_{pay}<T_1$', linewidth=line_thick)
plt.plot(T_new, conv_later_smooth*10000, label='$T_1<T_{pay}<T_2$', linewidth=line_thick)
plt.plot(T_new, conv_after_smooth*10000, label='$T_2<T_{pay}$', linewidth=line_thick)
# plt.plot(T_new, libor_smooth, label='$libor$')
# plt.axvline(x=0.5)
plt.legend(prop={'size':14}, bbox_to_anchor=(1, 0.4))
plt.axis([0, 10, -10, 35])
plt.grid(True, linewidth=grid_thick)
# plt.title(u'Поправка к форвардной LIBOR ставке, bps(0.01%)', fontsize=15)
plt.ylabel('$CA(t, T_i, T_{i+1})$, bps', fontsize=legend_size)
plt.xlabel(u'$T_i$, years', fontsize=legend_size)

plt.axhline(asymp1, c='black', ls='--')
plt.axhline(asymp2, c='black', ls='--')
plt.axhline(asymp3, c='black', ls='--')
plt.axhline(asymp4, c='black', ls='--')

plt.text(10.1, asymp1, round(asymp1, 2))
plt.text(10.1, asymp2, round(asymp2, 2))
plt.text(10.1, asymp3, round(asymp3, 2))
plt.text(10.1, asymp4, round(asymp4, 2))

# plt.yticks([asymp1, asymp2, asymp3, asymp4], [round(asymp1, 2), round(asymp2, 2), round(asymp3, 2), round(asymp4, 2)])

plt.tight_layout()
plt.show()

fig.savefig(folder + 'conv-adj_comp.png', dpi=fig.dpi, transparent=True)
# Out:
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   after removing the cwd from sys.path.
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   """
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: `spline` is deprecated!
# ...

# %% [markdown]
# ## Опционы

# %%
tau = 0.5
a = 0.7
b = 0.05
theta = a * b
sigma = 0.1

# %%
def F(x):
    return scipy.stats.norm.cdf(x)

# %%
def Cpl(t, T1, T2, K):
    I = (sigma**2 / a**2) * (1/(2*a) - 1/(2*a) * np.e ** (-2*a*(T1-t)) -\
                           1/a * np.e**(-a*(T2-T1)) + 1/(a) * np.e**(-a*(T1+T2) + 2*a*t) + \
                           1/(2*a) * np.e**(-2*a*(T2-T1)) - 1/(2*a) * np.e**(-2*a*(T2-t))) 
        
    l = (np.log((1+(T2-T1)*K)/(P(t,T1)/P(t,T2))) + 0.5*I)/(I**(0.5))
    
    return P(t, T1)**2 / P(t, T2) * np.e**I * F(2*I**0.5-l) - (1+(T2-T1)*K) * P(t, T1) * F(I**0.5 - l)

# %%
def Caplet(t, T1, T2, K):
    L = libor(t, T1, T2)
    d1 = (np.log(L/K) + 0.5*sigma**2 * (T1 - t))/(sigma*(T1 - t)**0.5)
    d2 = d1 - sigma * (T1 - t)**0.5
    return (T2-T1)*P(t, T2)*(L*F(d1) - K*F(d2))

# %%
def Florlet2(t, T1, T2, K):
    L = libor(t, T1, T2)
    d1 = (np.log(L/K) + 0.5*sigma**2 * (T1 - t))/(sigma*(T1 - t)**0.5)
    d2 = d1 - sigma * (T1 - t)**0.5
    return (T2-T1)*P(t, T2)*(-L*F(-d1) + K*F(-d2))

# %%
def Floorlet(t, T1, T2, K):
    return Caplet(t, T1, T2, K) - (T2-T1)*P(t, T2)*(libor(t, T1, T2) - K)

# %%
def Fl(t, T1, T2, K):
    return Cpl(t, T1, T2, K) - (T2-T1)*P(t, T1)*(libor(t, T1, T2) + convexity_adj(t, T1, T2) - K)

# %%
sigma = 0.1

# %%
tau = 0.5
a = 0.7
b = 0.05
theta = a * b
sigma = 0.1
T_n = 30.
r_t = 0.05

R_t = np.arange(0, 1, 0.001)
K = 0.05
T1 = 0.5
T2 = 1
cap1 = np.zeros(len(R_t))
cap2 = np.zeros(len(R_t))

fl1 = np.zeros(len(R_t))
fl2 = np.zeros(len(R_t))

for i in np.arange(len(R_t)):
    r_t=R_t[i]
    cap1[i] = Cpl(0, T1, T2, K)
    cap2[i] = Caplet(0, T1, T2, K)
    
    fl1[i] = Fl(0, T1, T2, K)
    fl2[i] = Floorlet(0, T1, T2, K)

# %%
Cpl(0, 0.5, 1, 0.01)
# Out:
# 0.23153263799629997

# %%
fig = plt.figure(figsize=(8, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(R_t*100, cap1, color=(0, 0, 0), label=u"in-arrears caplet", linewidth=line_thick, ls="-.")
plt.plot(R_t*100, cap2, color=(0, 0, 0), label=u"standard caplet", linewidth=line_thick)
plt.grid(True, linewidth=grid_thick)
plt.axis([0, 13, 0, 0.025])
# plt.title(u'Цена call-опциона на ставку LIBOR', fontsize=15)
plt.ylabel('$Cpl$, \$', fontsize=legend_size)
plt.xlabel(u'$LIBOR$, %', fontsize=legend_size)
plt.legend(prop={'size':legend_size})
plt.tight_layout()
plt.show()

fig.savefig(folder + 'caps.png', dpi=fig.dpi, transparent=True)

# %%
fig = plt.figure(figsize=(8, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(R_t*100, fl1, color=(0, 0, 0),  label=u"in-arrears floorlet", linewidth=line_thick, ls="-.")
plt.plot(R_t*100, fl2, color=(0, 0, 0), label=u"standard floorlet", linewidth=line_thick)
plt.grid(True, linewidth=grid_thick)
plt.axis([0, 25, 0, 0.02])
# plt.title(u'Цена put-опциона на ставку LIBOR', fontsize=15)
plt.ylabel('$Fl$, \$', fontsize=legend_size)
plt.xlabel(u'$LIBOR$, %', fontsize=legend_size)
plt.legend(prop={'size':legend_size})
plt.tight_layout()
plt.show()

fig.savefig(folder + 'floors.png', dpi=fig.dpi, transparent=True)

# %%
tau = 0.5
b = 0.05
theta = a * b
sigma = 0.1
T_n = 30.
r_t = 0.05

a = 1.6
sigma = 0.1
vol = np.arange(0.001, 0.9, 0.001)
cpl_vol = np.zeros(len(vol))
j = 0
for i in vol:
    sigma = i
    cpl_vol[j] = Cpl(0, 0.5, 1, 0.04)
    j += 1
    
fig = plt.figure(figsize=(8, 6), dpi= 80, facecolor='w', edgecolor='k')    
plt.plot(vol, cpl_vol)  
plt.ylabel('$Cpl$, \$', fontsize=legend_size)
plt.xlabel(u'$\sigma$', fontsize=legend_size)
plt.show()
fig.savefig(folder + 'test.png', dpi=fig.dpi, transparent=True)

# %%
plt.plot(np.arange(10), P(np.arange(10), 10))

# %%
r_t=0.05
Caplet(0, T1, T2, K) - (T2-T1)*P(t, T2)*(libor(t, T1, T2) - K)
# Out:
# C:\Users\THINK\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\THINK\Anaconda2\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\THINK\Anaconda2\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\THINK\Anaconda2\lib\site-packages\scipy\stats\_distn_infrastructure.py:1738: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= self.b) & cond0
# nan

# %%
P(0, 1)
# Out:
# 1.0118577289453237

# %% [markdown]
# ## Quanto convexity

# %%
tau = 0.5
a_d = 0.7
b_d = 0.05
theta_d = a_d * b_d
sigma_d = 0.1
r_d = 0.06

# %%
tau = 0.5
a_f = 0.7
b_f = 0.05
theta_f = a_f * b_f
sigma_f = 0.1
r_f = 0.1

# %%
sigma_x = 0.1

# %%
ro_df = 0.7
ro_dx = 0.5
ro_fx = 0.5

corrm = [[1, ro_df, ro_dx],[ro_df, 1, ro_fx],[ro_dx, ro_fx, 1]]
am = scipy.linalg.sqrtm(corrm)

# %%
am
# Out:
# array([[0.90587574, 0.35815318, 0.22608724],
#        [0.35815318, 0.90587574, 0.22608724],
#        [0.22608724, 0.22608724, 0.94750679]])

# %%
a11, a12, a13 = am[0]
a21, a22, a23 = am[1]
a31, a32, a33 = am[2]

# %%
# a11, a12, a13 = 0,0,0
# a21, a22, a23 = 0,0,0
# a31, a32, a33 = 0,0,0

# %%
np.matmul(am,am.T)
# Out:
# array([[1. , 0.7, 0.5],
#        [0.7, 1. , 0.5],
#        [0.5, 0.5, 1. ]])

# %%
am.T
# Out:
# array([[0.90587574, 0.35815318, 0.22608724],
#        [0.35815318, 0.90587574, 0.22608724],
#        [0.22608724, 0.22608724, 0.94750679]])

# %%
X_t = 1

# %%
def B_d(t, T):
    return (1 - np.e ** (- a_d * (T - t))) / a_d


def A_d(t, T):
    return np.e ** ((B_d(t, T) - (T - t)) * (theta_d / a_d - sigma_d ** 2 / (2 * a_d ** 2)) - sigma_d ** 2 * B_d(t, T) ** 2 / (4 * a_d))

def P_d(t, T):
    return A_d(t, T) * np.e ** (- r_d * B_d(t, T))

# %%
def B_f(t, T):
    return (1 - np.e ** (- a_f * (T - t))) / a_f


def A_f(t, T):
    return np.e ** ((B_f(t, T) - (T - t)) * (theta_f / a_f - sigma_f ** 2 / (2 * a_f ** 2)) - sigma_f ** 2 * B_f(t, T) ** 2 / (4 * a_f))

def P_f(t, T):
    return A_f(t, T) * np.e ** (- r_f * B_f(t, T))

# %%
def libor(t, T1, T2):
    return (P_d(t, T1) - P_d(t, T2)) / ((T2-T1) * P_d(t, T2))

# %%
def I1(t, T1, T2):
    return -2*(sigma_d/a_d)**2 * (T1 - t - np.e**(-a_d*(T2-T1))/a_d + np.e**(-a_d*(T2-t))/a_d - 1/a_d + np.e**(-a_d*(T1-t))/a_d + \
                                np.e**(-a_d*(T2-T1))/(2*a_d) - np.e**(-a_d*(T2 + T1 - 2*t))/(2*a_d))

# %%
def I2(t, T1, T2):
    return (1 + a11**2 + a12**2 + a13**2)*(sigma_d**2)/(a_d**2) * (T1-t - 2*np.e**(-a_d*(T2-T1))/a_d + 2*np.e**(-a_d*(T2-t))/a_d + \
                                                      np.e**(-2*a_d*(T2-T1))/(2*a_d) - np.e**(-2*a_d*(T2-t))/(2*a_d))

# %%
def I3(t, T1, T2):
    return 2*ro_df*sigma_d*sigma_f / (a_d * a_f) * (T1 - t - 1/a_f + np.e**(-a_f*(T1-t))/a_f - 1/a_d + np.e**(-a_d*(T1-t))/a_d + 1/(a_d + a_f) - \
                                   np.e**(-(a_d + a_f)*(T1-t))/(a_f + a_d))

# %%
def I4(t, T1, T2):
    return - (sigma_f**2)*(1 - (a21**2 + a22**2 + a23**2))/(a_f**2) * (T1-t - 2/a_f + 2*np.e**(-a_f*(T1-t))/a_f + 1/(2*a_f) - \
                                                          np.e**(-2*a_f*(T1-t))/(2*a_f))

# %%
def I5(t, T1, T2):
    return 2*sigma_x*sigma_d*ro_dx/a_d * (T1-t-1/a_d + np.e**(-a_d*(T1-t))/a_d)

# %%
def I6(t, T1, T2):
    return -2*sigma_x*sigma_f*(ro_fx - (a21*a31 + a22*a32 + a23*a33))/a_f * (T1-t-1/a_f + np.e**(-a_f*(T1-t))/a_f)

# %%
def I7(t, T1, T2):
    return -2*sigma_d*sigma_f*(a11*a21 + a12*a22 + a13*a23) / (a_d * a_f) * (T1-t - 1/a_f + np.e**(-a_f*(T1-t))/a_f - np.e**(-a_d*(T2-T1))/a_d + \
                                                            np.e**(-a_d*(T2-t))/a_d + np.e**(-a_d*(T2-T1))/(a_d + a_f) - \
                                                            np.e**(-a_d*(T2-t) -a_f*(T1-t))/(a_d + a_f))

# %%
def I8(t, T1, T2):
    return -2*sigma_x*sigma_d*(a11*a31 + a12*a32 + a13*a33) / (a_d) * (T1-t - np.e**(-a_d*(T2-T1))/a_d + np.e**(-a_d*(T2-t))/a_d)

# %%
def I(t, T1, T2):
    return np.e**(0.5 * (I1(t, T1, T2) + I2(t, T1, T2) + I3(t, T1, T2) + I4(t, T1, T2) + I5(t, T1, T2) + \
                         I6(t, T1, T2) + I7(t, T1, T2) + I8(t, T1, T2)))

# %%
def CA(t, T1, T2):
    return 1/(T2-T1) * P_d(t, T1) / (P_f(t, T1) * X_t) * (X_t*P_f(t, T1)/P_d(t, T1)*(P_d(t, T1)/P_d(t, T2)*I(t, T1, T2) - 1))

# %%
def CA1(t, T1, T2):
     return 1/(T2-T1) *(P_d(t, T1)/P_d(t, T2)*I(t, T1, T2) - 1)

# %%
print CA(0, 0, 0.5)
print libor(0, 0, 0.5)
# Out:
# 0.058966905203039044
# 0.058966905203

# %%
T = np.linspace(0, 10, 100)

# %%
plt.plot(T, CA(0, T, T+0.5))
plt.ylabel("CA, bps")
plt.xlabel("$T_i$, years")
plt.show()

# %%
plt.plot(T, libor(0, T, T+0.5))
plt.ylabel("libor")
plt.xlabel("$T_i$, years")
plt.show()

# %%
plt.plot(T, (CA(0, T, T+0.5) - libor(0, T, T+0.5))*10000)
plt.ylabel("CA, %")
plt.xlabel("$T_i$, years")
plt.show()

# %%
tau = 0.5
a_f = 0.7
b_f = 0.05
theta_f = a_f * b_f
sigma_f = 0.2
r_f = 0.05

tau = 0.6
a_d = 0.7
b_d = 0.05
theta_d = a_d * b_d
sigma_d = 0.1
r_d = 0.08

plt.plot(T, (CA(0, T, T+0.5) - libor(0, T, T+0.5))*10000)

tau = 0.5
a_f = 0.7
b_f = 0.05
theta_f = a_f * b_f
sigma_f = 0.3
r_f = 0.05

tau = 0.6
a_d = 0.7
b_d = 0.05
theta_d = a_d * b_d
sigma_d = 0.2
r_d = 0.08

plt.plot(T, (CA(0, T, T+0.5) - libor(0, T, T+0.5))*10000)

plt.ylabel("CA, bps")
plt.xlabel("$T_i$, years")
plt.show()

# %%
t = 0
T1 = 2
T2 = T1+2.5
aa = I1(t, T1, T2) + I2(t, T1, T2) + I3(t, T1, T2) + I4(t, T1, T2) + I5(t, T1, T2) + \
                         I6(t, T1, T2) + I7(t, T1, T2) + I8(t, T1, T2)

# %%
I3(t, T1, T2)
# Out:
# 0.029615420128212572

# %%
x = 1 + 1 + \
9

# %%
P_f(1, 4)-P_d(1, 4)
# Out:
# 0.06465855313841928
